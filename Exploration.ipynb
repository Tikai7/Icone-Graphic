# %%
import pandas as pd

# %%
df = pd.read_csv("output/doctr/output_moyen/analysis.csv")

# %%
df[df["expected"].isna()]
# Out:
#                                                  file  expected  \
# 0   13946_520475011_TER_03_La_Perruche_475g_MINI_R...       NaN
# 1     13946_DOYPACK_CASSONADE_DOYPACK_BIO_500GR-V.jpg       NaN
# 2                     144318_SACH_BOND_PURSL_2KG5.jpg       NaN
# 3                146496_SACH_BOND_CEPES_MORCE_1KG.jpg       NaN
# 4   170950605_ETQ_ETB_ESCAL_PORC_PANE_300G_TONNI_p...       NaN
# 5        2896_BTE_TARTI_CRAQU_SARAS_SS_GLUTE_270g.jpg       NaN
# 6             3251514251007_BTE_MARIE_FONDA_CHOCO.jpg       NaN
# 7         3251516304008_BTE_MARIE_TARTE_POMME_BIO.jpg       NaN
# 8   3564708006759-02_SACH_TMA_CROQU_VITAL_CHIEN_10...       NaN
# 9            5900852072970_ETQ_NUTRI_BEBEL_400G_3.jpg       NaN
# 10  6000006733_ETUI_ABBAY_CREPE_ENROB_CHOCO_LAIT_9...       NaN
# 11  6000006830_ETUI_BPAYS_COOKI_PEPIT_CHOCO_NOISE_...       NaN
# 12  6000006885_ETUI_ABBAY_LES_GRAND_GOURM_BIO_160G...       NaN
# 22                     8856_ETUI_PLATO_LOUIS_320G.jpg       NaN
# ...
